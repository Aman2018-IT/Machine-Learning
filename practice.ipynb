# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 540.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.6 MB 4.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/11.6 MB 7.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/11.6 MB 8.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.6 MB 9.7 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.6 MB 10.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.6 MB 10.6 MB/s eta 0:00:01
#    ------------- -------------------------- 4.0/11.6 MB 10.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
